# %%
import numpy as np
import pandas as pd


np.random.seed(42)
n=100
df=pd.DataFrame({
    
    "Size_sqft": np.random.randint(500, 3500, n),
    "Bedrooms": np.random.randint(1, 6, n),
    "Bathrooms": np.random.randint(1, 4, n),
    "Age_years": np.random.randint(1, 40, n),
    "Distance_city_km": np.random.randint(1, 25, n),
    "Floor": np.random.randint(1, 15, n)
})

df["Price"] = (
    df["Size_sqft"] * 120 +
    df["Bedrooms"] * 15000 +
    df["Bathrooms"] * 10000 -
    df["Age_years"] * 3000 -
    df["Distance_city_km"] * 2000 +
    df["Floor"] * 500 +
    np.random.randint(-20000, 20000, n)
)

x=df.drop("Price", axis=1)
y=df["Price"]
df
# Out:
#     Size_sqft  Bedrooms  Bathrooms  Age_years  Distance_city_km  Floor   Price
# 0        1360         4          1          8                22      3  172431
# 1        1794         3          3         27                16      4  195189
# 2        1630         3          2         27                 8      2  168403
# 3        1595         1          2         34                13      1   98770
# 4        2138         3          1         21                21      7  224638
# ..        ...       ...        ...        ...               ...    ...     ...
# 95       2562         2          2         12                 5      4  311457
# 96        564         2          2          1                 9      1   87524
# 97       3068         4          2          1                24      7  389362
# 98       1867         5          2         34                 3      9  195924
# 99       1652         1          2         32                17     13   90144
#
# [100 rows x 7 columns]

# %%
import numpy as np
import pandas as pd


# Download latest version
path = kagglehub.dataset_download("amith1707/covid-epidemic-dataset")

print("Path to dataset files:", path)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 import pandas as pd
#       5 # Download latest version
# ----> 6 path = kagglehub.dataset_download("amith1707/covid-epidemic-dataset")
#       8 print("Path to dataset files:", path)
#       9 df
#
# NameError: name 'kagglehub' is not defined

# %%
df

# %%
import numpy as np
import pandas as pd
data=pd.read_csv(r"C:\Users\arjun\Desktop\anjali practice pandas data.txt")
data
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 data=pd.read_csv(r"C:\Users\arjun\Desktop\anjali practice pandas data.txt")
#       4 data
#
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\arjun\Downloads\archive (1)\Teen_Mental_Health_Dataset.csv")
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...
